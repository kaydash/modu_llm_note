# %% [markdown]
# #  RAG 성능평가 개요
#
# ### **학습 목표:** RAGAS를 사용한 RAG 성능 평가 프로세스를 이해한다
#
# ---

# %% [markdown]
# ## 환경 설정 및 준비

# %% [markdown]
# `(1) Env 환경변수`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# `(2) 기본 라이브러리`

# %%
import os
from glob import glob

from pprint import pprint
import json

import uuid

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# `(3) langfuase handler 설정`

# %%
#from langfuse.callback import CallbackHandler
from langfuse.langchain import CallbackHandler

# LangChain 콜백 핸들러 생성
langfuse_handler = CallbackHandler()

# 정상 작동 확인
#langfuse_handler.auth_check() 

from langfuse import get_client
langfuse = get_client()
langfuse.auth_check()  # 인증 확인
# Out:
# True

# %% [markdown]
# ---
#
# ## RAG 시스템 성능 평가
#
# - **RAG 기술의 핵심**: 외부 지식 검색과 LLM 결합으로 응답 품질 향상
#
# - **평가 기준**: LLM-as-judge 방식으로 사실성, 관련성, 충실도, 유용성 평가
#
# - **체계적인 A/B 테스트**: 각 컴포넌트별 성능 비교 및 영향도 분석으로 최적 구성 도출
#
# - **평가 방법론**: 오프라인(참조답변 기반), 온라인(실시간), 페어와이즈(비교) 평가 구분
#
# <center>
# <img src="ref/rag_evaluation.png" alt="rag" align="center" border="0"  width="1000" height=auto>
# </center>
# <center>
# <img src="ref/rag_evaluation_target.png" alt="rag" align="center" border="0"  width="800" height=auto>
# </center>
#
#
# ---
#
# ### **평가 대상(Evaluation Target)**
#
# - **검색(Retrieval)** 단계:
#     1. 관련 문서와 쿼리 간의 연관성(Relevance)을 통해 검색된 문서가 쿼리의 정보 요구를 얼마나 잘 충족하는지 평가
#     1. 관련 문서와 후보 문서 간의 정확성(Accuracy)을 통해 시스템이 적절한 문서를 식별하는 능력을 측정
#
# - **생성(Generation)** 단계:
#     1. 응답과 쿼리의 연관성(Relavance)
#     1. 응답과 관련 문서 간의 충실도(Faithfulness)
#     1. 응답과 샘플 응답 간의 정확성(Correctness)
#
# - 추가 고려사항:
#     - **핵심 성능 지표**: Latency(응답 속도), Diversity(검색 다양성), Noise Robustness(잡음 내구성)
#     - **안전성 평가**: Negative Rejection(불충분 정보 거부), Counterfactual Robustness(오정보 식별)
#     - **사용자 경험**: Readability(가독성), Toxicity(유해성), Perplexity(복잡성) 등 추가 고려
#
#
# [출처] https://arxiv.org/abs/2405.07437

# %% [markdown]
# ---
#
# ### **평가 데이터셋 구축(Evaluation Dataset)**
#
# - **데이터셋 구성 방식**: LLM 기반 새로운 데이터셋 생성 (Synthetic Data)
#
# - **맞춤형 데이터셋** 구축으로 RAG 시스템의 실용성 평가 강화
#
#
# - [실습] : **Ragas** (https://docs.ragas.io/en/stable/) 활용
#
#     - **RAG 시스템 평가**를 위한 오픈소스 프레임워크
#     - **실용성**: 자동화된 평가 파이프라인 구축 가능
#     - **주요 지표**:
#
#         1. **충실도(Faithfulness)**:
#             - 생성된 답변이 주어진 컨텍스트와 얼마나 일치하는지 평가
#
#         2. **답변 관련성(Answer Relevancy)**:
#             - 생성된 답변이 주어진 질문과 얼마나 관련이 있는지 평가
#
#         3. **컨텍스트 정확도(Context Precision)**:
#             - 검색된 컨텍스트들이 얼마나 적절하게 순위가 매겨졌는지 평가
#             - 0~1 사이의 값으로, 높을수록 좋음

# %% [markdown]
# `(1) LangChain 문서 준비`

# %%
from langchain_community.document_loaders import TextLoader

# 데이터 로드
def load_text_files(txt_files):
    data = []

    for text_file in txt_files:
        loader = TextLoader(text_file, encoding='utf-8')
        data += loader.load()

    return data

korean_txt_files = glob(os.path.join('data', '*_KR.md')) 
korean_data = load_text_files(korean_txt_files)

print('Korean data:')
pprint(korean_data)
# Out:
# Korean data:
# [Document(metadata={'source': 'data\\리비안_KR.md'}, page_content='Rivian Automotive, Inc.는 2009년에 설립된 미국의 전기 자동차 제조업체, 자동차 기술 및 야외 레크리에이션 회사입니다.\n\n**주요 정보:**\n\n- **회사 유형:** 상장\n- **거래소:** NASDAQ: RIVN\n- **설립:** 2009년 6월, 플로리다 주 록ledge\n- **설립자:** R. J. 스캐린지\n- **본사:** 미국 캘리포니아 주 어바인\n- **서비스 지역:** 북미\n- **주요 인물:** R. J. 스캐린지 (CEO)\n- **제품:** 전기 자동차, 배터리\n- **생산량 (2023):** 57,232대\n- **서비스:** 전기 자동차 충전, 자동차 보험\n- **수익 (2023):** 44억 3천만 미국 달러\n- **순이익 (2023):** -54억 미국 달러\n- **총 자산 (2023):** 168억 미국 달러\n- **총 자본 (2023):** 91억 4천만 미국 달러\n- **직원 수 (2023년 12월):** 16,790명\n- **웹사이트:** rivian.com\n\n**개요**\n\nRivian은 "스케이트보드" 플랫폼(R1T 및 R1S 모델)을 기반으로 한 전기 스포츠 유틸리티 차량(SUV), 픽업 트럭 및 전기 배달 밴(Rivian EDV)을 생산합니다. R1T 배송은 2021년 말에 시작되었습니다. 회사는 2022년에 미국에서 충전 네트워크를 시작하여 2024년에 다른 차량에도 개방했습니다. 생산 공장은 일리노이 주 노멀에 있으며, 다른 시설은 미국, 캐나다, 영국 및 세르비아의 여러 주에 있습니다.\n\n**역사**\n\n**초창기 (2009–15):**\n\n- 2009년 R. J. 스캐린지가 Mainstream Motors로 설립.\n- 2011년 Rivian Automotive로 사명 변경.\n- 처음에는 스포츠카 프로토타입(R1)에 집중했지만 전기 및 자율 주행 차량으로 전환.\n\n**생산 준비 (2016–20):**\n\n- 2017년 일리노이 주 노멀에 있는 이전 Mitsubishi Motors 제조 공장을 1,600만 달러에 인수.\n- 2017년 12월, 첫 두 제품인 R1T (픽업 트럭)와 R1S (SUV)를 공개.\n- 생산은 2020년에 시작될 예정.\n\n**첫 모델 배송; IPO; 감원 및 확장 (2021–24):**\n\n- R1T 배송은 2021년 9월에 시작되어 Rivian은 완전 전기 픽업을 소비자 시장에 출시한 최초의 자동차 제조업체가 됨.\n- 2021년 11월, Rivian은 IPO를 통해 135억 달러를 조달하여 상장 회사가 됨.\n- Ford와 Rivian은 전기 자동차 공동 개발 계획을 취소.\n- 2022년 3월, Rivian은 부품 비용으로 인해 R1T 및 R1S의 가격 인상을 발표했으며, 이후 소급 적용에 대해 사과.\n- 2022년 7월, Rivian은 6%의 인력 감축을 발표.\n- 2022년 9월, 유럽에서 전기 밴을 생산하기 위해 Mercedes-Benz Group과 합작 투자를 발표했지만 나중에 취소됨.\n- 2022년 10월, 느슨한 토크 볼트로 인해 13,000대의 차량을 자발적으로 리콜.\n- 2023년 6월, Tesla의 북미 충전 시스템(NACS) 채택을 발표.\n- 2023년 6월, "A Better Route Planner"(ABRP) EV 경로 계획 앱을 개발한 Iternio 인수.\n- 2023년 10월, Amazon과의 독점 계약을 종료하여 Rivian이 다른 상업 고객에게 공급할 수 있도록 허용.\n- 2024년 2월, 급여 직원 10% 감축 발표.\n- 2024년 3월, 더 작은 가격대의 R2 SUV 및 R3 공개.\n\n**Volkswagen과의 파트너십 (2024)**\n\n- 2024년 6월, Volkswagen Group은 전기 아키텍처 및 소프트웨어 기술 개발을 목표로 Rivian에 최대 50억 달러를 투자할 의향을 발표.\n\n**차량**\n\n- **R1T:** 4개의 전기 모터가 장착된 픽업 트럭. 배터리 크기는 105 kWh에서 180 kWh까지 다양함.\n- **R1S:** 첫 번째 Rivian 플랫폼의 스포츠 유틸리티 차량(SUV) 버전.\n- **Electric Delivery Van (EDV):** 상업용 전기 밴으로, 주로 Amazon용으로 설계되어 사용됨.\n- **R2:** 더 작고 저렴한 SUV로, 새로운 플랫폼에서 2026년 초에 출시될 예정.\n- **R3:** 출시 예정인 전기 소형 SUV.\n\n**EV 충전**\n\nRivian은 미국과 캐나다 전역에 공공 충전소 네트워크를 개발하고 있습니다. Rivian은 2021년에 Waypoint 충전기 설치를 시작했지만 2023년 4월에 Rivian Adventure Network가 Rivian 이외의 차량에도 개방될 것이라고 발표되었습니다. Rivian은 또한 2025년 모델 연도부터 북미에서 차량에 북미 충전 시스템(NACS)을 채택할 예정입니다.\n\n**시설**\n\n- **Irvine, California:** 차량 엔지니어링 및 설계에 중점을 둔 본사.\n- **Normal, Illinois:** 차량 부품을 생산하고 조립을 수행하는 제조 공장.\n- **Plymouth, Michigan:** 차량 엔지니어링, 프로토타입 제작, 공급망 및 회계에 중점을 둡니다.\n- **Palo Alto, California:** 소프트웨어 개발 및 엔지니어링에 중점을 둡니다.\n- Carson, California 및 Woking, England에 추가 사무실이 있습니다.\n- 애틀랜타 동쪽에 있는 새로운 50억 달러 규모의 배터리 및 조립 공장은 보류 중입니다.\n\n**재정**\n\nRivian의 재무 성과는 상당한 수익 성장과 상당한 순손실로 특징지어집니다.\n\n| 연도 | 수익 (백만 USD) | 순이익 (백만 USD) | 총 자산 (백만 USD) |\n| ---- | --------------- | ----------------- | ------------------ |\n| 2020 | 0               | -1,018            | 4,602              |\n| 2021 | 55              | -4,688            | 22,294             |\n| 2022 | 1,658           | -6,752            | 17,876             |\n| 2023 | 4,434           | -5,432            | 16,778             |\n\n**최대 주주**\n\n2023년 12월 현재 최대 주주는 Amazon, T. Rowe Price International, The Vanguard Group, BlackRock 및 Fidelity Investments였습니다.\n\n**협력**\n\nRivian은 Alex Honnold, the Honnold Foundation, Casa Pueblo, Ewan McGregor, Charley Boorman, Yakima 및 MAXTRAX와 파트너십을 맺었습니다.\n\n**소송**\n\n- 2020년 7월, Tesla는 Rivian이 독점 정보를 훔치고 직원을 빼갔다고 주장하며 소송을 제기했습니다.\n- 2021년 3월, Illinois Automobile Dealers Association은 Rivian과 Lucid Motors가 소비자에게 직접 판매했다는 이유로 소송을 제기했습니다.\n- 2021년 11월, 전 VP Laura Schwab은 차별 혐의로 소송을 제기하고 차량 가격 책정 및 안전 표준에 대한 우려를 제기했습니다.\n'),
#  Document(metadata={'source': 'data\\테슬라_KR.md'}, page_content='Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사입니다. 이 회사는 전기 자동차(BEV), 고정형 배터리 에너지 저장 장치, 태양 전지판, 태양광 지붕널 및 관련 제품/서비스를 설계, 제조 및 판매합니다. 2003년 7월 Martin Eberhard와 Marc Tarpenning이 Tesla Motors로 설립했으며, Nikola Tesla를 기리기 위해 명명되었습니다. Elon Musk는 2004년 Tesla의 초기 자금 조달을 주도하여 2008년에 회장 겸 CEO가 되었습니다.\n\nTesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (2012), Model X (2015), Model 3 (2017), Model Y (2020), Semi (2022) 및 Cybertruck (2023)으로 이어졌습니다. 이 회사는 세계에서 가장 가치 있는 회사 중 하나이며 2020년 7월 이후 가장 가치 있는 자동차 제조업체입니다. Tesla는 2021~2022년, 그리고 2024년에 다시 한 번 한때 1조 달러의 가치를 달성했습니다. 2023년에는 배터리 전기 자동차 시장에서 가장 큰 점유율(19.9%)을 차지했으며 Forbes Global 2000에서 69위에 랭크되었습니다.\n\nTesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Musk의 논란의 여지가 있는 발언과 관련된 소송, 정부 조사 및 비판에 직면했습니다.\n\n## 역사\n\n### 창립 (2003–2004)\n\nTesla Motors, Inc.는 2003년 7월 1일에 Martin Eberhard와 Marc Tarpenning에 의해 설립되었으며, 각각 CEO와 CFO를 역임했습니다. Ian Wright는 얼마 지나지 않아 합류했습니다. 2004년 2월, Elon Musk는 750만 달러의 시리즈 A 자금 조달을 주도하여 회장 겸 최대 주주가 되었습니다. J. B. Straubel은 2004년 5월 CTO로 합류했습니다. 다섯 명 모두 공동 설립자로 인정받고 있습니다.\n\n### Roadster (2005–2009)\n\nElon Musk는 주류 차량으로 확장하기 전에 프리미엄 스포츠카로 시작하는 전략에 초점을 맞춰 적극적인 역할을 수행했습니다. 후속 자금 조달에는 Valor Equity Partners (2006)와 Sergey Brin, Larry Page, Jeff Skoll과 같은 기업가의 투자가 포함되었습니다.\n\n2007년 8월, Eberhard는 CEO에서 물러나라는 요청을 받았고, Tarpenning은 2008년 1월에 이어졌습니다. Michael Marks는 Ze\'ev Drori가 인수하기 전에 임시 CEO를 역임했으며, Musk는 2008년 10월에 인수했습니다. Eberhard는 2009년 6월 Musk를 상대로 소송을 제기했지만 나중에 기각되었습니다.\n\nRoadster 생산은 2008년에 시작되었습니다. 2009년 1월까지 Tesla는 1억 8,700만 달러를 모금하고 147대의 자동차를 인도했습니다. 2009년 6월, Tesla는 미국 에너지부로부터 4억 6,500만 달러의 대출을 받았으며, 2013년 5월에 이자와 함께 상환했습니다.\n\n### IPO, Model S 및 Model X (2010–2015)\n\n2010년 5월, Tesla는 캘리포니아 주 프리몬트의 NUMMI 공장을 Toyota로부터 인수했습니다. 이 회사는 2010년 6월 NASDAQ에 상장하여 2억 2,600만 달러를 조달했습니다.\n\nTesla는 2012년 6월 Model S 고급 세단을 출시했습니다. Model S는 여러 자동차 상을 받았으며 노르웨이(2013년 9월)와 전 세계(2015년 및 2016년)에서 가장 많이 팔린 전기 자동차가 되었습니다. Tesla는 2013년 7월 NASDAQ-100에 합류했습니다.\n\n2014년, Tesla는 운전자 지원 시스템인 Autopilot을 발표했습니다. Tesla는 2015년 4월 Powerwall 및 Powerpack과 함께 에너지 저장 시장에 진출하여 일주일 만에 8억 달러의 주문을 받았습니다. Model X SUV는 2015년 9월에 출시되었습니다.\n\n### SolarCity 및 Model 3 (2016–2018)\n\nTesla는 2016년 11월 SolarCity를 26억 달러에 인수하여 Tesla Energy를 설립했습니다. 2017년 2월, Tesla Motors는 사명을 Tesla, Inc.로 변경했습니다.\n\nModel 3 세단은 2016년 4월에 공개되어 일주일 만에 325,000건 이상의 예약이 접수되었습니다. "생산 지옥"으로 묘사된 생산 문제로 인해 지연이 발생했습니다. 2018년 말까지 Model 3는 세계에서 가장 많이 팔린 전기 자동차(2018-2021)가 되었습니다. 2018년 8월, Musk는 Tesla를 비상장으로 전환할 계획을 발표했지만 실현되지 않았고 논란과 SEC의 증권 사기 혐의로 이어졌습니다.\n\n### 글로벌 확장 및 Model Y (2019–현재)\n\n2019년 7월부터 2020년 6월까지 Tesla는 4분기 연속 흑자를 보고했으며 S&P 500에 추가되었습니다. 2020년에는 주가가 크게 상승했으며 시가 총액은 다음 9개의 대형 자동차 제조업체를 합친 것보다 많았습니다.\n\nModel Y 중형 크로스오버 SUV는 2019년 3월에 소개되었으며 배송은 2020년 3월에 시작되었습니다. Tesla는 Gigafactory Shanghai (2019), Gigafactory Berlin (2020) 및 Gigafactory Texas (2020)로 생산 능력을 확장했습니다.\n\n2023년 3월, Tesla는 잠재적인 관세 영향으로 인해 지연된 Gigafactory Mexico에 대한 계획을 발표했습니다. COVID-19 팬데믹 초기에 Tesla는 2020년 3월에 프리몬트 공장을 폐쇄하고 지방 당국과의 분쟁 후 2020년 5월 11일에 재개장했습니다. Tesla는 2021년 12월에 법적 본사를 Gigafactory Texas로 이전했지만 Megafactory (2022)와 Palo Alto의 글로벌 엔지니어링 본사(2023)로 캘리포니아에서의 입지를 확장했습니다.\n\n2021년 초, Tesla는 Bitcoin에 15억 달러를 투자하고 환경 문제로 인해 중단하기 전에 잠시 결제 수단으로 허용했습니다. 2022년 7월까지 Tesla는 Bitcoin 보유량의 약 75%를 매각했습니다. 2023년 5월과 2024년 2월 사이에 북미 EV 제조업체는 Tesla의 북미 충전 표준으로 전환할 계획을 발표했습니다.\n\n2023년 11월, Tesla는 Cybertruck 배송을 시작했습니다. 2024년 4월, 회사는 직원 10% 감축을 발표하고 6월에 법인 설립지를 델라웨어에서 텍사스로 이전했습니다. 2024년 10월, Tesla는 미래의 차량 호출 서비스인 Tesla Network를 위해 Cybercab 및 Robovan의 컨셉 버전을 공개했습니다.\n\n2024년 12월, 델라웨어 법원은 부적절한 이사회 승인을 이유로 Elon Musk의 560억 달러 급여 패키지를 거부했습니다.\n\n## 자동차 제품 및 서비스\n\n2024년 11월 현재 Tesla는 Model S, Model X, Model 3, Model Y, Semi 및 Cybertruck의 6가지 차량 모델을 제공합니다. 다음은 Tesla 모델 목록입니다.\n\n| Tesla 모델 |          |       |                  |\n| :--------- | :------- | :---- | :--------------- |\n| 이름       | 제조년도 | 좌석  | 참고             |\n| Roadster   | 2008     | 2     | 2012년에 단종    |\n| Model S    | 2012     | 5/7   |                  |\n| Model X ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 문장을 구분하여 분할 - 정규표현식 사용 (문장 구분자: 마침표, 느낌표, 물음표 다음에 공백이 오는 경우)
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base",    # TikToken 인코더 이름
    separators=['\n\n', '\n', r'(?<=[.!?])\s+'],   # 구분자
    chunk_size=300,
    chunk_overlap=0,
    is_separator_regex=True,      # 구분자가 정규식인지 여부
    keep_separator=True,          # 구분자 유지 여부
)

korean_docs = text_splitter.split_documents(korean_data)

print("한국어 문서 수:", len(korean_docs))
print("-"*100)
print(korean_docs[0].metadata)
pprint(korean_docs[0].page_content)
print("-"*100)
print(korean_docs[1].metadata)
pprint(korean_docs[1].page_content)
# Out:
# 한국어 문서 수: 39
# ----------------------------------------------------------------------------------------------------
# {'source': 'data\\리비안_KR.md'}
# ('Rivian Automotive, Inc.는 2009년에 설립된 미국의 전기 자동차 제조업체, 자동차 기술 및 야외 레크리에이션 '
#  '회사입니다.\n'
#  '\n'
#  '**주요 정보:**')
# ----------------------------------------------------------------------------------------------------
# {'source': 'data\\리비안_KR.md'}
# ('- **회사 유형:** 상장\n'
#  '- **거래소:** NASDAQ: RIVN\n'
#  '- **설립:** 2009년 6월, 플로리다 주 록ledge\n'
#  '- **설립자:** R. J. 스캐린지\n'
#  '- **본사:** 미국 캘리포니아 주 어바인\n'
#  '- **서비스 지역:** 북미\n'
#  '- **주요 인물:** R. J. 스캐린지 (CEO)\n'
#  '- **제품:** 전기 자동차, 배터리\n'
#  '- **생산량 (2023):** 57,232대\n'
#  '- **서비스:** 전기 자동차 충전, 자동차 보험\n'
#  '- **수익 (2023):** 44억 3천만 미국 달러\n'
#  '- **순이익 (2023):** -54억 미국 달러\n'
#  '- **총 자산 (2023):** 168억 미국 달러')

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

# OpenAI Embeddings 모델을 로드
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# Chroma 벡터 저장소 생성하기
vector_store = Chroma.from_documents(
    documents=korean_docs,
    embedding=embedding_model,    
    collection_name="db_korean_cosine", 
    persist_directory="./chroma_db",
    collection_metadata = {'hnsw:space': 'cosine'}, # l2, ip, cosine 중에서 선택 
)

# 결과 확인
print(f"저장된 Document 개수: {len(vector_store.get()['ids'])}")
# Out:
# 저장된 Document 개수: 39

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

# OpenAI Embeddings 모델을 로드
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# Chroma 벡터 저장소 로드
vector_store = Chroma(
    embedding_function=embedding_model,    
    collection_name="db_korean_cosine", 
    persist_directory="./chroma_db",
)

# 결과 확인
print(f"저장된 Document 개수: {len(vector_store.get()['ids'])}")
# Out:
# 저장된 Document 개수: 39

# %% [markdown]
# `(2) LLM 설정`

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings

# LLM과 임베딩 모델 초기화
generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings(model="text-embedding-3-small"))

# %% [markdown]
# `(3) Test Data 생성`

# %%
from ragas.testset.persona import Persona

# 페르소나 정의 (다양한 관점에서 질문 생성)
personas = [
    Persona(
        name="graduate_researcher",  # 박사과정 연구원: 심도 있는 분석적 질문
        role_description="미국 전기차 시장을 연구하는 한국인 박사과정 연구원으로, 전기차 정책과 시장 동향에 대해 깊이 있는 분석을 하고 있습니다. 한국어만을 사용합니다.",
    ),
    Persona(
        name="masters_student",    # 석사과정 학생: 개념 이해를 위한 질문
        role_description="전기차 산업을 공부하는 한국인 석사과정 학생으로, 미국 전기차 시장의 기초적인 개념과 트렌드를 이해하려 노력하고 있습니다. 한국어만을 사용합니다.",
    ),
    Persona(
        name="industry_analyst",   # 산업 분석가: 실무 중심적 질문
        role_description="한국 자동차 회사에서 미국 전기차 시장을 분석하는 주니어 연구원으로, 실무적인 시장 데이터와 경쟁사 동향에 관심이 많습니다. 한국어만을 사용합니다.",
    ),
    Persona(
        name="undergraduate_student",  # 학부생: 기초적인 학습 질문
        role_description="자동차 공학을 전공하는 한국인 학부생으로, 미국 전기차 기술과 시장에 대해 기본적인 지식을 습득하고자 합니다. 한국어만을 사용합니다.",
    )
]

# %%
from ragas.testset import TestsetGenerator

# TestsetGenerator 생성
generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings, persona_list=personas)

# 합성 데이터 생성
dataset = generator.generate_with_langchain_docs(korean_docs, testset_size=50)
# Out:
# Applying SummaryExtractor:   0%|          | 0/34 [00:00<?, ?it/s]
# Applying CustomNodeFilter:   0%|          | 0/39 [00:00<?, ?it/s]
# Node 89c738d1-a1c3-4183-810b-6e087c19c55e does not have a summary. Skipping filtering.
# Node 0d51e742-0ea0-471e-970a-3c9e044677cd does not have a summary. Skipping filtering.
# Node b2cc243b-4716-4908-bf20-35c0d3bc0530 does not have a summary. Skipping filtering.
# Node 8056517f-0029-4d95-9d74-eb753b0047db does not have a summary. Skipping filtering.
# Node c01b08b6-59f9-4a50-9488-94043440d775 does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/112 [00:00<?, ?it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/51 [00:00<?, ?it/s]

# %%
# 노트북에 이미 정의된 영어 문서 사용
english_txt_files = glob(os.path.join("data", "*_EN.md"))
english_data = load_text_files(english_txt_files)
english_docs = text_splitter.split_documents(english_data)

# 영어 문서로 데이터셋 생성 (안전한 테스트)
dataset_en = generator.generate_with_langchain_docs(
    english_docs,
    testset_size=10
)

print("영어 문서로 테스트 완료!")
# Out:
# Applying SummaryExtractor:   0%|          | 0/18 [00:00<?, ?it/s]
# Applying CustomNodeFilter:   0%|          | 0/19 [00:00<?, ?it/s]
# Node 34206c8d-4da6-4c2f-a276-aa5b017228f1 does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/56 [00:00<?, ?it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/12 [00:00<?, ?it/s]
# 영어 문서로 테스트 완료!

# %%
test_data = dataset.to_pandas()
test_data
# Out:
#                                            user_input  \
# 0                  Rivian Automotive, Inc.는 어떤 회사인가요?
# 1                       리브니 회사 배터리 어떻게 중요해요 전기차 시장에서?
# 2                   2023년에 리비안의 총 자본과 직원 수는 각각 얼마인가요?
# 3                 2022년 Rivian 미국 충전 네트워크 시작에 대해 알려줘?
# 4       R1S가 Rivian의 전기차 라인업에서 어떤 역할을 하는지 설명해 주시겠습니까?
# 5                         R1T 배송은 2021년 9월에 언제 시작됬나요?
# 6                                            R3가 뭐에요?
# 7                                    R1S what car is?
# 8                2023년 4월에 Rivian이 발표한 중요한 변화는 무엇인가요?
# 9   Could you please explain the specific roles an...
# 10  What role does Amazon play as a major sharehol...
# 11                      Rivian 관련 Tesla 소송 내용은 무엇인가요?
# 12             Nikola Tesla는 Tesla, Inc.와 어떤 관련이 있나요?
# 13                   Tesla Model Y 언제 나왔고 시장에서 위치 어때?
# 14     Who is J. B. Straubel in the history of Tesla?
# 15  Sergey Brin은 전기차 기업의 초기 자금 조달에서 어떤 역할을 했으며, 그의...
# 16  NUMMI 공장은 Tesla의 미국 전기차 생산에 어떤 역할을 했으며, 언제 인수되...
# 17  How did Elon Musk's leadership and funding inf...
# 18  how rivian first launch full electric pickup i...
# 19  How does Tesla's strategy of battery cost redu...
# 20  How does Tesla, Inc. integrate its electric ve...
# 21  How is the transition to the North American Ch...
# 22  Tesla 고전압 DC 급속 충전 네트워크랑 Tesla IPO 어떻게 연결돼? 그리...
# 23  When did Tesls start the Cybertruck delivry la...
# 24  R1T electrik pickup truck waht are its main fe...
# 25  How do Rivian's main products, such as electri...
# 26  Rivian의 R1T 전기 픽업 트럭과 Tesla의 차세대 차량은 각각 어떤 특징과...
# 27  tesla vs rivian lawsuit irvine california head...
# 28  2024년 3월에 공개된 더 작은 가격대의 R2 컴팩트 SUV와 R3 전기 소형 S...
# 29  Tesla battery supply and production how relate...
# 30  How is the transition to North American EV cha...
# 31  What are the key features of the Model Y as an...
# 32  how dose adoption of Tesla North American Char...
# 33  Tesla Roadster (2nd generation) 2025년 생산예정인데, ...
# 34  Tesla how SolarCity acquisition in 2016 linked...
# 35  How did Elon Musk's role evolve at Tesla from ...
# 36  Who is Elon Musk and hw did he influnce Tesla'...
# 37  Tesal Motors는 언제 설립되었고, Model 3의 초기 반응과 생산 문제는...
# 38  Gigafactory 베를린과 Gigafactory Texas는 각각 언제 개장했으...
# 39  2024년 6월 Volkswagen과의 파트너십 발표가 Rivian의 전기차 생산 ...
# 40       tesla semi 와 model x 의 트리 모터 구동 레이아웃 차이는 뭐야?
# 41                        Rivian 언제 설립됐고 2009년 6월 맞아?
# 42  Tesla Energy 언제 설립됐고, 어떤 제품과 서비스를 제공하는지, 그리고 T...
# 43  Tesla Semi 언제 출시됐고, Tesla가 2024년에 다시 1조 달러 가치 ...
# 44  Elon Musk의 560억 달러 급여 패키지가 2024년 12월 델라웨어 법원에서...
# 45  Rivian 2022년 9월에 Mercedes-Benz Group과 유럽 전기 밴 ...
# 46  What is the Cybercab, and how does Tesla plan ...
# 47  Can you explain how Tesla Motors, Inc. was fou...
# 48  How did the production history and financial m...
# 49  How is Rivian planning to adopt the NACS stand...
# 50  Tesla의 Autopilot 기능은 언제 처음 발표되었으며, Tesla가 이 기능...
#
#                                    reference_contexts  \
# 0   [Rivian Automotive, Inc.는 2009년에 설립된 미국의 전기 자동...
# 1   [- **회사 유형:** 상장\n- **거래소:** NASDAQ: RIVN\n- *...
# 2   [- **총 자본 (2023):** 91억 4천만 미국 달러\n- **직원 수 (2...
# 3   [**개요**\n\nRivian은 "스케이트보드" 플랫폼(R1T 및 R1S 모델)을...
# 4   [- 2009년 R. J. 스캐린지가 Mainstream Motors로 설립.\n-...
# 5   [- R1T 배송은 2021년 9월에 시작되어 Rivian은 완전 전기 픽업을 소비...
# 6   [- 2022년 10월, 느슨한 토크 볼트로 인해 13,000대의 차량을 자발적으로...
# 7   [**Volkswagen과의 파트너십 (2024)**\n\n- 2024년 6월, V...
# 8   [**EV 충전**\n\nRivian은 미국과 캐나다 전역에 공공 충전소 네트워크를...
# 9   [- **Irvine, California:** 차량 엔지니어링 및 설계에 중점을 ...
# 10  [| 연도 | 수익 (백만 USD) | 순이익 (백만 USD) | 총 자산 (백만 ...
# 11  [- 2020년 7월, Tesla는 Rivian이 독점 정보를 훔치고 직원을 빼갔다...
# 12  [Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사입니다. 이 회사...
# 13  [Tesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (2...
# 14  [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 15  [Elon Musk는 주류 차량으로 확장하기 전에 프리미엄 스포츠카로 시작하는 전략...
# 16  [Roadster 생산은 2008년에 시작되었습니다. 2009년 1월까지 Tesla...
# 17  [<1-hop>\n\nTesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 ...
# 18  [<1-hop>\n\n| Tesla 모델 |          |       |   ...
# 19  [<1-hop>\n\nTesla의 전략은 배터리 비용을 줄이기 위해 고가, 소량 차...
# 20  [<1-hop>\n\nTesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 ...
# 21  [<1-hop>\n\n2021년 초, Tesla는 Bitcoin에 15억 달러를 투...
# 22  [<1-hop>\n\n- **회사 유형:** 상장\n- **거래소:** NASDAQ...
# 23  [<1-hop>\n\n2021년 초, Tesla는 Bitcoin에 15억 달러를 투...
# 24  [<1-hop>\n\n**Volkswagen과의 파트너십 (2024)**\n\n- ...
# 25  [<1-hop>\n\n- **회사 유형:** 상장\n- **거래소:** NASDAQ...
# 26  [<1-hop>\n\n**Volkswagen과의 파트너십 (2024)**\n\n- ...
# 27  [<1-hop>\n\n## 파트너\n\nTesla는 Panasonic과 파트너십을 ...
# 28  [<1-hop>\n\n**Volkswagen과의 파트너십 (2024)**\n\n- ...
# 29  [<1-hop>\n\nTesla의 전략은 배터리 비용을 줄이기 위해 고가, 소량 차...
# 30  [<1-hop>\n\n2021년 초, Tesla는 Bitcoin에 15억 달러를 투...
# 31  [<1-hop>\n\n**개요**\n\nRivian은 "스케이트보드" 플랫폼(R1T...
# 32  [<1-hop>\n\n- 2022년 10월, 느슨한 토크 볼트로 인해 13,000대...
# 33  [<1-hop>\n\n### 발표된 제품\n\n- **Roadster (2세대):*...
# 34  [<1-hop>\n\nTesla는 2016년 11월 SolarCity를 26억 달러...
# 35  [<1-hop>\n\nTesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 ...
# 36  [<1-hop>\n\nTesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 ...
# 37  [<1-hop>\n\nTesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 ...
# 38  [<1-hop>\n\n| 개장 | 이름                | 도시     ...
# 39  [<1-hop>\n\n**Volkswagen과의 파트너십 (2024)**\n\n- ...
# 40  [<1-hop>\n\n- **Model S:** 리프트백 차체 스타일과 듀얼 모터,...
# 41  [<1-hop>\n\n- **회사 유형:** 상장\n- **거래소:** NASDAQ...
# 42  [<1-hop>\n\nTesla는 2016년 11월 SolarCity를 26억 달러...
# 43  [<1-hop>\n\n2024년 12월, 델라웨어 법원은 부적절한 이사회 승인을 이...
# 44  [<1-hop>\n\n2024년 12월, 델라웨어 법원은 부적절한 이사회 승인을 이...
# 45  [<1-hop>\n\n- R1T 배송은 2021년 9월에 시작되어 Rivian은 완...
# 46  [<1-hop>\n\n### 발표된 제품\n\n- **Roadster (2세대):*...
# 47  [<1-hop>\n\nTesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함...
# 48  [<1-hop>\n\n### 발표된 제품\n\n- **Roadster (2세대):*...
# 49  [<1-hop>\n\n**EV 충전**\n\nRivian은 미국과 캐나다 전역에 공...
# 50  [<1-hop>\n\nTesla는 무선 업데이트를 사용하여 강력한 온보드 컴퓨터를 ...
#
#                                             reference  \
# 0   Rivian Automotive, Inc.는 2009년에 설립된 미국의 전기 자동차...
# 1   리브니 회사는 전기 자동차와 배터리를 주요 제품으로 생산하며, 북미 지역에서 서비스...
# 2   2023년에 리비안의 총 자본은 91억 4천만 미국 달러이며, 2023년 12월 기...
# 3   Rivian은 2022년에 미국에서 충전 네트워크를 시작했으며, 이 네트워크는 20...
# 4   R1S는 Rivian이 2017년 12월에 공개한 첫 두 제품 중 하나로, SUV ...
# 5   R1T 배송은 2021년 9월에 시작되었으며, 이로 인해 Rivian은 완전 전기 ...
# 6              R3는 2024년 3월에 공개된 더 작은 가격대의 SUV 모델입니다.
# 7   R1S는 Rivian의 첫 번째 플랫폼을 기반으로 한 스포츠 유틸리티 차량(SUV)...
# 8   2023년 4월에 Rivian은 Rivian Adventure Network가 Ri...
# 9   The Plymouth, Michigan facility focuses on veh...
# 10  As of December 2023, Amazon is listed as one o...
# 11  2020년 7월, Tesla는 Rivian이 독점 정보를 훔치고 직원을 빼갔다고 주...
# 12  Tesla, Inc.는 2003년 Martin Eberhard와 Marc Tarpe...
# 13  Tesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (20...
# 14  J. B. Straubel joined Tesla in May 2004 as the...
# 15  Sergey Brin은 Valor Equity Partners와 함께 2006년에 ...
# 16  Tesla는 2010년 5월에 캘리포니아 주 프리몬트에 위치한 NUMMI 공장을 T...
# 17  Elon Musk played a crucial role in Tesla's ear...
# 18  Rivian started delivering its fully electric p...
# 19  Tesla's strategy to reduce battery costs invol...
# 20  Tesla, Inc. operates as a multinational compan...
# 21  The transition to the North American Charging ...
# 22  Tesla의 고전압 DC 급속 충전 네트워크인 Supercharger는 2012년에...
# 23  Tesla started the Cybertruck delivery launch i...
# 24  R1T electric pickup truck, developed by Rivian...
# 25  Rivian, a publicly traded company on NASDAQ (R...
# 26  Rivian의 R1T 전기 픽업 트럭은 4개의 전기 모터가 장착되어 있으며, 배터리...
# 27  Tesla는 2020년 7월 Rivian이 독점 정보를 훔치고 직원을 빼갔다고 주장...
# 28  2024년 3월, Rivian은 더 작은 가격대의 R2 컴팩트 SUV와 R3 전기 ...
# 29  Tesla는 CATL, LG Energy Solution 및 Panasonic에서 ...
# 30  The transition to North American EV charging s...
# 31  The Model Y is a mid-size crossover SUV offere...
# 32  Tesla가 개발한 북미 충전 표준(NACS)은 2023년 6월에 채택되었으며, 이...
# 33  Tesla Roadster (2세대)는 2017년에 공개되었으며 2025년에 생산될...
# 34  Tesla acquired SolarCity in November 2016 for ...
# 35  Elon Musk led the initial funding of Tesla Mot...
# 36  Elon Musk는 2004년에 Tesla의 초기 자금 조달을 주도했으며, 2008...
# 37  Tesla Motors는 2003년 7월 Martin Eberhard와 Marc T...
# 38  Gigafactory 베를린은 2022년에 독일 그륀하이데에서 개장하였고, Giga...
# 39  2024년 6월 Volkswagen Group은 전기 아키텍처 및 소프트웨어 기술 ...
# 40  Model X는 듀얼 모터 또는 트리 모터, 전륜 구동 레이아웃을 갖춘 중형 고급 ...
# 41  Rivian은 2009년 6월에 플로리다 주 록ledge에서 설립되었으며, 2009...
# 42  Tesla Energy는 2016년 11월에 Tesla가 SolarCity를 26억...
# 43  Tesla Semi는 2022년에 출시되었으며, Tesla는 2024년에 다시 한 ...
# 44  2024년 12월 델라웨어 법원은 Elon Musk의 560억 달러 급여 패키지를 ...
# 45  2022년 9월에 Rivian은 유럽에서 전기 밴을 생산하기 위해 Mercedes-...
# 46  The Cybercab is a planned 2-seater battery ele...
# 47  Tesla Motors, Inc. was founded on July 1, 2003...
# 48  The original Tesla Roadster production started...
# 49  Rivian plans to adopt the North American Charg...
# 50  Tesla의 Autopilot 기능은 2014년에 처음 발표되었습니다. 이 기능은 ...
#
#                         synthesizer_name
# 0   single_hop_specifc_query_synthesizer
# 1   single_hop_specifc_query_synthesizer
# 2   single_hop_specifc_query_synthesizer
# 3   single_hop_specifc_query_synthesizer
# 4   single_hop_specifc_query_synthesizer
# 5   single_hop_specifc_query_synthesizer
# 6   single_hop_specifc_query_synthesizer
# 7   single_hop_specifc_query_synthesizer
# 8   single_hop_specifc_query_synthesizer
# 9   single_hop_specifc_query_synthesizer
# 10  single_hop_specifc_query_synthesizer
# 11  single_hop_specifc_query_synthesizer
# 12  single_hop_specifc_query_synthesizer
# 13  single_hop_specifc_query_synthesizer
# 14  single_hop_specifc_query_synthesizer
# 15  single_hop_specifc_query_synthesizer
# 16  single_hop_specifc_query_synthesizer
# 17  multi_hop_abstract_query_synthesizer
# 18  multi_hop_abstract_query_synthesizer
# 19  multi_hop_abstract_query_synthesizer
# 20  multi_hop_abstract_query_synthesizer
# 21  multi_hop_abstract_query_synthesizer
# 22  multi_hop_abstract_query_synthesizer
# 23  multi_hop_abstract_query_synthesizer
# 24  multi_hop_abstract_query_synthesizer
# 25  multi_hop_abstract_query_synthesizer
# 26  multi_hop_abstract_query_synthesizer
# 27  multi_hop_abstract_query_synthesizer
# 28  multi_hop_abstract_query_synthesizer
# 29  multi_hop_abstract_query_synthesizer
# 30  multi_hop_abstract_query_synthesizer
# 31  multi_hop_abstract_query_synthesizer
# 32  multi_hop_abstract_query_synthesizer
# 33  multi_hop_abstract_query_synthesizer
# 34  multi_hop_specific_query_synthesizer
# 35  multi_hop_specific_query_synthesizer
# 36  multi_hop_specific_query_synthesizer
# 37  multi_hop_specific_query_synthesizer
# 38  multi_hop_specific_query_synthesizer
# 39  multi_hop_specific_query_synthesizer
# 40  multi_hop_specific_query_synthesizer
# 41  multi_hop_specific_query_synthesizer
# 42  multi_hop_specific_query_synthesizer
# 43  multi_hop_specific_query_synthesizer
# 44  multi_hop_specific_query_synthesizer
# 45  multi_hop_specific_query_synthesizer
# 46  multi_hop_specific_query_synthesizer
# 47  multi_hop_specific_query_synthesizer
# 48  multi_hop_specific_query_synthesizer
# 49  multi_hop_specific_query_synthesizer
# 50  multi_hop_specific_query_synthesizer

# %%
# CSV 저장
test_data.to_csv('./data/ragas_testset.csv', index=False)

# %% [markdown]
# ### **[실습] 평가 데이터셋 합성**
#
# - "data/*_EN.md" 파일들을 문서로 가져와서 청크 길이를 300 토큰 단위로 분할
# - ragas 활용 테스트 데이터셋 5개 생성

# %%
from langchain_community.document_loaders import TextLoader

# "data/*_EN.md" 파일 로드
def load_text_files(txt_files):
    data = []

    for text_file in txt_files:
        loader = TextLoader(text_file, encoding='utf-8')
        data += loader.load()

    return data

english_txt_files = glob(os.path.join('data', '*_EN.md'))
english_data = load_text_files(english_txt_files)

print('English data:')
pprint(english_data)
# Out:
# English data:
# [Document(metadata={'source': 'data\\Rivian_EN.md'}, page_content='Rivian Automotive, Inc. is an American electric vehicle manufacturer, automotive technology, and outdoor recreation company founded in 2009.\n\n**Key Facts:**\n\n- **Company Type:** Public\n- **Traded As:** NASDAQ: RIVN\n- **Founded:** June 2009, in Rockledge, Florida\n- **Founder:** R. J. Scaringe\n- **Headquarters:** Irvine, California, U.S.\n- **Area Served:** North America\n- **Key People:** R. J. Scaringe (CEO)\n- **Products:** Electric vehicles, batteries\n- **Production Output (2023):** 57,232 vehicles\n- **Services:** Electric vehicle charging, vehicle insurance\n- **Revenue (2023):** US$4.43 billion\n- **Net Income (2023):** US$−5.4 billion\n- **Total Assets (2023):** US$16.8 billion\n- **Total Equity (2023):** US$9.14 billion\n- **Number of Employees (December 2023):** 16,790\n- **Website:** rivian.com\n\n**Overview**\n\nRivian produces electric sport utility vehicles (SUVs), pickup trucks on a "skateboard" platform (R1T and R1S models), and electric delivery vans (Rivian EDV). Deliveries of the R1T began in late 2021. The company launched a charging network in the United States in 2022, opening it to other vehicles in 2024. Its production plant is located in Normal, Illinois, with other facilities in various US states, Canada, UK, and Serbia.\n\n**History**\n\n**Beginnings (2009–15):**\n\n- Founded in 2009 by R. J. Scaringe as Mainstream Motors.\n- Renamed Rivian Automotive in 2011.\n- Initially focused on a sports car prototype (R1) but shifted to electric and autonomous vehicles.\n\n**Setting up Production (2016–20):**\n\n- Acquired a former Mitsubishi Motors manufacturing plant in Normal, Illinois, in 2017 for $16 million.\n- In December 2017, revealed its first two products: the R1T (pickup truck) and R1S (SUV).\n- Production was scheduled to begin in 2020.\n\n**Shipment of First Models; IPO; Lay-offs and Expansion (2021–24):**\n\n- R1T shipments began in September 2021, making Rivian the first automaker to bring a fully electric pickup to the consumer market.\n- In November 2021, Rivian became a public company through an IPO, raising $13.5 billion.\n- Ford and Rivian cancelled plans to co-develop an electric vehicle.\n- In March 2022, Rivian announced price increases for the R1T and R1S due to component costs, later apologizing for the retroactive impact.\n- In July 2022, Rivian announced a workforce reduction of 6%.\n- In September 2022, a joint venture with Mercedes-Benz Group to produce electric vans in Europe was announced, but later cancelled.\n- October 2022, issued a voluntary recall of 13,000 vehicles due to loose torque bolts.\n- June 2023, announced adoption of Tesla\'s North American Charging System (NACS).\n- June 2023, acquired Iternio, the company behind the "A Better Route Planner" (ABRP) EV route-planning app.\n- October 2023, ended exclusivity deal with Amazon, allowing Rivian to supply other commercial customers.\n- February 2024, announced a 10% reduction of salaried workforce.\n- March 2024, unveiled the R2 SUV and R3, with a smaller price tag.\n\n**Partnership with Volkswagen (2024)**\n\n- In June 2024, Volkswagen Group announced an intention to invest up to $5 billion in Rivian, aimed at developing electrical architecture and software technology.\n\n**Vehicles**\n\n- **R1T:** A pickup truck with four electric motors. Battery sizes range from 105 kWh to 180 kWh.\n- **R1S:** A sport utility vehicle (SUV) version of the first Rivian platform.\n- **Electric Delivery Van (EDV):** An electric van for commercial purposes, primarily designed for and used by Amazon.\n- **R2:** A smaller, less-expensive SUV on a new platform, scheduled to launch in early 2026.\n- **R3:** An upcoming electric compact SUV.\n\n**EV Charging**\n\nRivian is developing a network of public charging stations across the United States and Canada. Rivian began installing Waypoint chargers in 2021, but in April 2023 it was announced that the Rivian Adventure Net ...
#  Document(metadata={'source': 'data\\Tesla_EN.md'}, page_content='Tesla, Inc. is an American multinational automotive and clean energy company. It designs, manufactures, and sells electric vehicles (BEVs), stationary battery energy storage devices, solar panels, solar shingles, and related products/services. Founded in July 2003 by Martin Eberhard and Marc Tarpenning as Tesla Motors, it was named in honor of Nikola Tesla. Elon Musk led Tesla\'s initial funding in 2004, becoming chairman and later CEO in 2008.\n\nTesla\'s vehicle production began with the Roadster in 2008, followed by the Model S (2012), Model X (2015), Model 3 (2017), Model Y (2020), Semi (2022), and Cybertruck (2023). It is among the world\'s most valuable companies and the most valuable automaker since July 2020. Tesla briefly reached trillion-dollar status in 2021-2022 and again in 2024. In 2023, it held the largest share of the battery electric vehicle market (19.9%) and was ranked 69th in the Forbes Global 2000.\n\nTesla has faced lawsuits, government scrutiny, and criticism related to whistleblower retaliation, worker rights violations, safety defects, lack of public relations, and controversial statements from Musk.\n\n## History\n\n### Founding (2003–2004)\n\nTesla Motors, Inc. was established on July 1, 2003, by Martin Eberhard and Marc Tarpenning, who served as CEO and CFO, respectively. Ian Wright joined shortly after. In February 2004, Elon Musk led a $7.5 million Series A funding round, becoming chairman and the largest shareholder. J. B. Straubel joined as CTO in May 2004. All five are recognized as co-founders.\n\n### Roadster (2005–2009)\n\nElon Musk played an active role, focusing on a strategy of starting with a premium sports car before expanding to mainstream vehicles. Subsequent funding rounds included investments from Valor Equity Partners (2006) and entrepreneurs like Sergey Brin, Larry Page, and Jeff Skoll.\n\nIn August 2007, Eberhard was asked to step down as CEO, followed by Tarpenning in January 2008. Michael Marks served as interim CEO before Ze\'ev Drori took over, succeeded by Musk in October 2008. Eberhard filed a lawsuit against Musk in June 2009, which was later dismissed.\n\nRoadster production began in 2008. By January 2009, Tesla had raised $187 million and delivered 147 cars. In June 2009, Tesla received a $465 million loan from the U.S. Department of Energy, repaid in May 2013 with interest.\n\n### IPO, Model S, and Model X (2010–2015)\n\nIn May 2010, Tesla acquired the NUMMI plant in Fremont, California, from Toyota. The company went public on NASDAQ in June 2010, raising $226 million.\n\nTesla launched the Model S luxury sedan in June 2012. The Model S received several automotive awards and became the best-selling electric car in Norway (September 2013) and worldwide (2015 and 2016). Tesla joined the NASDAQ-100 in July 2013.\n\nIn 2014, Tesla announced Autopilot, a driver-assistance system. Tesla entered the energy storage market in April 2015 with the Powerwall and Powerpack, receiving $800 million in orders within a week. The Model X SUV was launched in September 2015.\n\n### SolarCity and Model 3 (2016–2018)\n\nTesla acquired SolarCity in November 2016 for $2.6 billion, forming Tesla Energy. In February 2017, Tesla Motors changed its name to Tesla, Inc.\n\nThe Model 3 sedan was unveiled in April 2016, receiving over 325,000 reservations in a week. Production challenges, described as "production hell," led to delays. By the end of 2018, the Model 3 became the world\'s best-selling electric car (2018-2021). In August 2018, Musk announced plans to take Tesla private, which did not materialize and resulted in controversy and a securities fraud charge from the SEC.\n\n### Global expansion and Model Y (2019–present)\n\nFrom July 2019 to June 2020, Tesla reported four consecutive profitable quarters and was added to the S&P 500. In 2020, its share price increased significantly, and its market capitalization exceeded the next ...

# %%
# English 문서들을 300 토큰 단위로 분할
english_docs = text_splitter.split_documents(english_data)

print("English 문서 수:", len(english_docs))
print("-"*100)
print("첫 번째 영어 문서 메타데이터:", english_docs[0].metadata)
print("첫 번째 영어 문서 내용:")
print(english_docs[0].page_content[:200] + "...")
print("-"*100)

# English 전용 페르소나 정의 (영어 질문 생성)
english_personas = [
    Persona(
        name="ev_researcher",
        role_description="An automotive industry researcher specializing in electric vehicle market analysis in the United States. Focuses on technical specifications and market trends. Uses English only.",
    ),
    Persona(
        name="business_analyst", 
        role_description="A business analyst studying the competitive landscape of electric vehicle companies. Interested in financial performance and strategic positioning. Uses English only.",
    ),
    Persona(
        name="technology_student",
        role_description="An engineering student learning about electric vehicle technology and innovations. Seeks to understand technical concepts and industry developments. Uses English only.",
    )
]

# English용 TestsetGenerator 생성
english_generator = TestsetGenerator(
    llm=generator_llm, 
    embedding_model=generator_embeddings, 
    persona_list=english_personas
)

# RAGAS 활용 테스트 데이터셋 5개 생성
english_testset = english_generator.generate_with_langchain_docs(
    english_docs, 
    testset_size=5
)

print("영어 테스트 데이터셋 생성 완료!")

# 결과 확인
english_test_data = english_testset.to_pandas()
print(f"생성된 테스트 데이터 수: {len(english_test_data)}")
print("\n생성된 테스트 데이터 샘플:")
print(english_test_data[['user_input', 'reference']].head())

# CSV 저장
english_test_data.to_csv('./data/testset_en.csv', index=False)
print("\n테스트 데이터가 'data/testset_en.csv'에 저장되었습니다.")
# Out:
# English 문서 수: 19
# ----------------------------------------------------------------------------------------------------
# 첫 번째 영어 문서 메타데이터: {'source': 'data\\Rivian_EN.md'}
# 첫 번째 영어 문서 내용:
# Rivian Automotive, Inc. is an American electric vehicle manufacturer, automotive technology, and outdoor recreation company founded in 2009.
#
# **Key Facts:**
#
# - **Company Type:** Public
# - **Traded As:*...
# ----------------------------------------------------------------------------------------------------
# Applying SummaryExtractor:   0%|          | 0/18 [00:00<?, ?it/s]
# Applying CustomNodeFilter:   0%|          | 0/19 [00:00<?, ?it/s]
# Node b90beda8-7ab8-48de-bd57-f6bd6f77fea3 does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/56 [00:00<?, ?it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/6 [00:00<?, ?it/s]
# 영어 테스트 데이터셋 생성 완료!
# 생성된 테스트 데이터 수: 6
#
# 생성된 테스트 데이터 샘플:
#                                           user_input  \
# 0                 Wher was Rivian founded in Florid?
# 1  Who is R. J. Scaringe and what is his role in ...
# 2  Can you explain what Cybercab is and how it co...
# 3  When Tesla started shipping the Cybertruck in ...
# 4  Can you explane how the deliveries of Tesla's ...
#
#                                            reference
# 0  Rivian Automotive, Inc. was founded in June 20...
# 1  R. J. Scaringe founded Rivian in 2009 original...
# 2  Cybercab is an upcoming two-passenger battery-...
# 3  Tesla began shipping the Cybertruck in Novembe...
# 4  Tesla's Model X, a mid-size luxury crossover S...
#
# 테스트 데이터가 'data/testset_en.csv'에 저장되었습니다.

# %% [markdown]
# ---
#
# ### **평가 지표(Evaluation Metric)**
#
# #### 1) **검색(Retrieval) 평가**
#
# - **Non-Rank Based Metrics**: Accuracy, Precision, Recall@k 등을 통해 관련성의 이진적 평가를 수행
#
# - **Rank-Based Metrics**: MRR(Mean Reciprocal Rank), MAP(Mean Average Precision)를 통해 검색 결과의 순위를 고려한 평가를 수행
#
# - **RAG 특화 지표**: 기존 검색 평가 방식의 한계를 보완하는 LLM-as-judge 방식 도입
#
# - **포괄적 평가**: 정확도, 관련성, 다양성, 강건성을 통합적으로 측정
#
# #### 2) **생성(Generation) 평가**
#
# - **전통적 평가**: ROUGE(요약), BLEU(번역), BertScore(의미 유사도) 지표 활용
#
# - **LLM 기반 평가**: 응집성, 관련성, 유창성을 종합적으로 판단하는 새로운 접근법 도입 (전통적인 참조 비교가 어려운 상황에서 유용)
#
# - **다차원 평가**: 품질, 일관성, 사실성, 가독성, 사용자 만족도를 포괄적 측정
#
# - **상세 프롬프트**와 **사용자 선호도** 기준으로 생성 텍스트 품질 평가

# %% [markdown]
# `(1) RAG 체인 - 평가 대상`

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 벡터 저장소 검색기 생성
retriever = vector_store.as_retriever(search_kwargs={"k": 5})

# RAG 체인 
llm = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# 템플릿 생성
template = """Answer the question based only on the following context:

[Context]
{context}

[Question]
{query}

[Answer]
"""
prompt = ChatPromptTemplate.from_template(template)

qa_chain = prompt | llm | StrOutputParser()

def format_docs(relevant_docs):
    return "\n".join(doc.page_content for doc in relevant_docs)


query = "Tesla는 언제 누가 만들었나?"

relevant_docs = retriever.invoke(query)
qa_chain.invoke({"context": format_docs(relevant_docs), "query": query})
# Out:
# 'Tesla는 2003년 7월 1일에 Martin Eberhard와 Marc Tarpenning에 의해 설립되었습니다.'

# %% [markdown]
# `(2) 평가 수행을 위한 데이터셋 전처리`

# %%
# 데이터 로드
import pandas as pd
testset = pd.read_excel('data/testset.xlsx')

# 데이터 확인
testset.head()
# Out:
#                                           user_input  \
# 0  Tesla, Inc.는 미국에서 어떤 역할을 하고 있으며, 이 회사의 주요 제품과 ...
# 1                    Forbes Global 2000에서 테슬라 순위 뭐야?
# 2                                 Tesla는 언제 누가 만들었나?
# 3                   Larry Page는 전기차 시장에서 어떤 역할을 했나요?
# 4                          Toyota와 Tesla의 관계는 무엇인가요?
#
#                                   reference_contexts  \
# 0  ['Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사입니다. 이 회...
# 1  ['Tesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (...
# 2  ['Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, M...
# 3  ["Elon Musk는 주류 차량으로 확장하기 전에 프리미엄 스포츠카로 시작하는 전...
# 4  ['Roadster 생산은 2008년에 시작되었습니다. 2009년 1월까지 Tesl...
#
#                                            reference  \
# 0  Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사로, 전기 자동차(...
# 1            테슬라는 Forbes Global 2000에서 69위에 랭크되었습니다.
# 2  Tesla Motors, Inc.는 2003년 7월 1일에 Martin Eberha...
# 3  Larry Page는 전기차 시장에서 Tesla의 후속 자금 조달에 투자한 기업가 ...
# 4  2010년 5월, Tesla는 캘리포니아 주 프리몬트의 NUMMI 공장을 Toyot...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer
# 2  single_hop_specifc_query_synthesizer
# 3  single_hop_specifc_query_synthesizer
# 4  single_hop_specifc_query_synthesizer

# %%
from ragas import EvaluationDataset

# 데이터셋 생성
dataset = []

# 각 행에 대해 RAG 체인을 호출하여 결과를 저장
for row in testset.itertuples():
    query = row.user_input   # 사용자 입력
    reference = row.reference  # 참조 답변
    relevant_docs = retriever.invoke(query)  # 검색된 문서
    response = qa_chain.invoke(      # RAG 체인 생성 답변 생성
        {
            "context": format_docs(relevant_docs),
            "query": query,
        },config={"callbacks": [langfuse_handler]})  
    
    dataset.append(
        {
            "user_input": query,
            "retrieved_contexts": [rdoc.page_content for rdoc in relevant_docs],
            "response": response,
            "reference": reference,
        }
    )

evaluation_dataset = EvaluationDataset.from_list(dataset)

# %%
# 데이터프레임 변환하여 확인 
evaluation_dataset.to_pandas().head()
# Out:
#                                           user_input  \
# 0  Tesla, Inc.는 미국에서 어떤 역할을 하고 있으며, 이 회사의 주요 제품과 ...
# 1                    Forbes Global 2000에서 테슬라 순위 뭐야?
# 2                                 Tesla는 언제 누가 만들었나?
# 3                   Larry Page는 전기차 시장에서 어떤 역할을 했나요?
# 4                          Toyota와 Tesla의 관계는 무엇인가요?
#
#                                   retrieved_contexts  \
# 0  [Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사입니다. 이 회사...
# 1  [Tesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (2...
# 2  [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 3  [Elon Musk는 주류 차량으로 확장하기 전에 프리미엄 스포츠카로 시작하는 전략...
# 4  [## 파트너\n\nTesla는 Panasonic과 파트너십을 맺고 있으며 리튬 공...
#
#                                             response  \
# 0  Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사로서 전기 자동차(...
# 1            Forbes Global 2000에서 테슬라는 69위에 랭크되었습니다.
# 2  Tesla는 2003년 7월 1일에 Martin Eberhard와 Marc Tarp...
# 3  Larry Page는 Tesla의 후속 자금 조달에 투자자로 참여하여 전기차 시장에...
# 4                          Toyota는 Tesla의 이전 파트너입니다.
#
#                                            reference
# 0  Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사로, 전기 자동차(...
# 1            테슬라는 Forbes Global 2000에서 69위에 랭크되었습니다.
# 2  Tesla Motors, Inc.는 2003년 7월 1일에 Martin Eberha...
# 3  Larry Page는 전기차 시장에서 Tesla의 후속 자금 조달에 투자한 기업가 ...
# 4  2010년 5월, Tesla는 캘리포니아 주 프리몬트의 NUMMI 공장을 Toyot...

# %%
# 데이터 저장
evaluation_dataset.to_pandas().to_csv('data/evaluation_dataset.csv', index=False)

# %% [markdown]
# ### **[실습] RAG 체인 구성 및 추론 실행**
#
# - "data/*_EN.md" 문서에 대한 RAG 체인을 구성
# - 이전에 구축한 테스트 데이터셋 5개에 대한 RAG 체인의 출력값을 생성

# %%
# 데이터 로드
testset = pd.read_csv('data/testset_en.csv')
testset.head(2)
# Out:
#                                           user_input  \
# 0                 Wher was Rivian founded in Florid?
# 1  Who is R. J. Scaringe and what is his role in ...
#
#                                   reference_contexts  \
# 0  ['Rivian Automotive, Inc. is an American elect...
# 1  ['Rivian produces electric sport utility vehic...
#
#                                            reference  \
# 0  Rivian Automotive, Inc. was founded in June 20...
# 1  R. J. Scaringe founded Rivian in 2009 original...
#
#                        synthesizer_name
# 0  single_hop_specifc_query_synthesizer
# 1  single_hop_specifc_query_synthesizer

# %%
# English 문서용 벡터 저장소 생성
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

# OpenAI Embeddings 모델 로드 (영어용)
embedding_model_en = OpenAIEmbeddings(model="text-embedding-3-small")

# Chroma 벡터 저장소 생성 (영어 문서용)
vector_store_en = Chroma.from_documents(
    documents=english_docs,
    embedding=embedding_model_en,    
    collection_name="db_english_cosine", 
    persist_directory="./chroma_db_en",
    collection_metadata={'hnsw:space': 'cosine'},
)

print(f"English 벡터 저장소에 저장된 Document 개수: {len(vector_store_en.get()['ids'])}")

# English 문서용 RAG 체인 구성
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 벡터 저장소 검색기 생성 (영어용)
retriever_en = vector_store_en.as_retriever(search_kwargs={"k": 5})

# RAG 체인 구성 (영어용)
llm_en = ChatOpenAI(model="gpt-4.1-mini", temperature=0)

# 영어용 템플릿 생성
template_en = """Answer the question based only on the following context:

[Context]
{context}

[Question]
{query}

[Answer]
"""
prompt_en = ChatPromptTemplate.from_template(template_en)

qa_chain_en = prompt_en | llm_en | StrOutputParser()

def format_docs_en(relevant_docs):
    return "\n".join(doc.page_content for doc in relevant_docs)

# 테스트 데이터셋에 대한 RAG 체인 출력값 생성
print("\n=== RAG 체인 추론 실행 ===")

# 결과 저장을 위한 리스트
rag_results = []

# 각 테스트 데이터에 대해 RAG 체인 실행
for idx, row in testset.iterrows():
    query = row['user_input']
    reference = row['reference']
    
    print(f"\n[질문 {idx+1}] {query}")
    
    # 관련 문서 검색
    relevant_docs = retriever_en.invoke(query)
    
    # RAG 체인으로 답변 생성
    response = qa_chain_en.invoke({
        "context": format_docs_en(relevant_docs), 
        "query": query
    }, config={"callbacks": [langfuse_handler]})
    
    print(f"[RAG 답변] {response}")
    print(f"[참조 답변] {reference}")
    print("-" * 80)
    
    # 결과 저장
    rag_results.append({
        "query": query,
        "rag_response": response,
        "reference": reference,
        "retrieved_contexts": [doc.page_content for doc in relevant_docs]
    })

# 결과를 DataFrame으로 변환하여 저장
import pandas as pd
rag_results_df = pd.DataFrame(rag_results)
rag_results_df.to_csv('data/rag_results_en.csv', index=False)

print(f"\n=== 완료 ===")
print(f"총 {len(rag_results)}개 질문에 대한 RAG 체인 출력값을 생성했습니다.")
print("결과가 'data/rag_results_en.csv'에 저장되었습니다.")
# Out:
# English 벡터 저장소에 저장된 Document 개수: 19
#
# === RAG 체인 추론 실행 ===
#
# [질문 1] Wher was Rivian founded in Florid?
# [RAG 답변] Rivian was founded in Rockledge, Florida.
# [참조 답변] Rivian Automotive, Inc. was founded in June 2009 in Rockledge, Florida.
# --------------------------------------------------------------------------------
#
# [질문 2] Who is R. J. Scaringe and what is his role in Rivian?
# [RAG 답변] R. J. Scaringe is the founder of Rivian Automotive, Inc. and serves as the company's CEO.
# [참조 답변] R. J. Scaringe founded Rivian in 2009 originally as Mainstream Motors. He led the company through its renaming to Rivian Automotive in 2011 and its shift from focusing on a sports car prototype to electric and autonomous vehicles.
# --------------------------------------------------------------------------------
#
# [질문 3] Can you explain what Cybercab is and how it compares to electric delivery vans like Rivian EDV in terms of their purpose and development?
# [RAG 답변] The provided context does not mention or describe "Cybercab." Therefore, based on the available information, there is no explanation of what Cybercab is or how it compares to electric delivery vans like the Rivian EDV in terms of purpose and development.
# [참조 답변] Cybercab is an upcoming two-passenger battery-electric self-driving car announced by Tesla, representing a new type of autonomous vehicle designed for passenger transport. In contrast, Rivian produces electric delivery vans known as Rivian EDV, which are part of their lineup including electric SUVs and pickup trucks built on a skateboard platform. While Cybercab focuses on autonomous passenger mobility, Rivian EDV serves the purpose of electric delivery, highlighting different applications of electric vehicle technology by Tesla and Rivian respectively.
# --------------------------------------------------------------------------------
#
# [질문 4] When Tesla started shipping the Cybertruck in November 2023, how does the announcement of the Cybercab concept in October 2024 relate to Tesla's plans for future vehicle offerings and ridehailing services?
# [RAG 답변] When Tesla started shipping the Cybertruck in November 2023, it marked the company's entry into the full-sized electric pickup truck market with a production vehicle available to customers. The subsequent announcement of the Cybercab concept in October 2024 relates to Tesla's plans for expanding its future vehicle offerings beyond traditional consumer vehicles into autonomous, purpose-built electric vehicles designed specifically for ridehailing services.
#
# The Cybercab is a two-passenger battery-electric self-driving car, and along with the Robovan (an electric autonomous van), it is intended for a future ridehailing service called the Tesla Network. This indicates Tesla's strategic move to develop specialized autonomous vehicles tailored for shared mobility and ridehailing, complementing its existing lineup of consumer vehicles like the Cybertruck. Thus, the Cybercab concept represents Tesla's vision to diversify its product portfolio and enter the autonomous ridehailing market, leveraging its expertise in electric vehicles and self-driving technology.
# [참조 답변] Tesla began shipping the Cybertruck in November 2023, marking a significant step in bringing this electric pickup truck to market. Following this, in October 2024, Tesla unveiled concept versions of the Cybercab, a two-passenger battery-electric self-driving car, and the Robovan, intended for a future ridehailing service called the Tesla Network. This progression from shipping the Cybertruck to introducing the Cybercab concept highlights Tesla's expanding focus on diverse electric vehicle offerings, including autonomous vehicles designed for ridehailing, indicating a strategic move towards integrating electric vehicle production with future mobility services.
# --------------------------------------------------------------------------------
#
# [질문 5] Can you explane how the deliveries of Tesla's Model X in September 2015 compare to Rivian's first electric pickup shipments in September 2021, considering the themes of September 2015 and September 2021?
# [RAG 답변] Based on the provided context, the deliveries of Tesla's Model X in September 2015 and Rivian's first electric pickup shipments in September 2021 represent significant milestones for each company, but with different thematic implications:
#
# - **Tesla's Model X (September 2015):** The launch and deliveries of the Model X marked Tesla's expansion into the electric SUV market, following the success of the Model S sedan. It was a luxury electric SUV that helped Tesla solidify its position as a leader in electric vehicles and advanced driver-assistance technology. This event was part of Tesla's broader growth phase, building on its early successes and expanding its product lineup.
#
# - **Rivian's R1T (September 2021):** The shipment of Rivian's R1T pickup truck was notable as it made Rivian the first automaker to bring a fully electric pickup truck to the consumer market. This represented a pioneering moment in the electric vehicle industry, targeting a new vehicle segment (electric pickups) that Tesla had not yet entered at that time. It also marked Rivian's transition from development to production and delivery.
#
# **Comparison:**
#
# - Both events occurred in September but six years apart, each marking a key product launch and delivery milestone for their respective companies.
# - Tesla's Model X deliveries in 2015 represented the company's move into the electric SUV segment, expanding its luxury EV offerings.
# - Rivian's R1T deliveries in 2021 represented a breakthrough as the first fully electric pickup truck available to consumers, opening a new market segment.
# - Tesla was already an established EV manufacturer by 2015, while Rivian was entering the market as a newer company launching its first product.
# - The Model X launch was part of Tesla's early growth and product diversification, whereas the R1T launch was a pioneering step in electrifying a traditionally combustion-engine dominated vehicle category.
#
# In summary, Tesla's Model X deliveries in September 2015 signified expansion within the electric SUV market by an established EV leader, while Rivian's R1T deliveries in September 2021 marked the debut of the first fully electric pickup truck, representing a new frontier in electric vehicle offerings.
# [참조 답변] Tesla's Model X, a mid-size luxury crossover SUV with unique falcon-wing rear doors, had its deliveries start in September 2015 after a prototype was shown earlier that year. In contrast, Rivian began shipments of its R1T, the first fully electric pickup truck available to consumers, in September 2021. While Tesla's Model X marked an advancement in luxury electric SUVs with innovative design features, Rivian's R1T represented a milestone as the first fully electric pickup entering the consumer market, highlighting different segments and timelines in electric vehicle development.
# --------------------------------------------------------------------------------
#
# [질문 6] What significant events related to electric vehicle companies occurred in June 2009 and June 2012, and how do they reflect the development timelines of Rivian Automotive and Tesla's Model S?
# [RAG 답변] In June 2009, Rivian Automotive was founded, marking the beginning of the company's journey in the electric vehicle industry. This event signifies the early stage of Rivian's development as an electric vehicle manufacturer.
#
# In June 2012, Tesla launched the Model S luxury sedan, a significant milestone that established Tesla as a leading electric vehicle producer with a commercially successful and award-winning product.
#
# These events reflect the development timelines of the two companies: Rivian was just starting its foundation and initial development in 2009, while by 2012, Tesla had already progressed to launching a flagship electric vehicle model, demonstrating an earlier market entry and product launch compared to Rivian.
# [참조 답변] In June 2009, Rivian Automotive, Inc. was founded in Rockledge, Florida, marking the establishment of a new American electric vehicle manufacturer focused on automotive technology and outdoor recreation. Three years later, in June 2012, Tesla began deliveries of its Model S, a full-size luxury car with a liftback body style and a dual-motor, all-wheel drive layout, whose development started before 2007. These dates highlight key milestones in the electric vehicle industry: Rivian's company foundation in June 2009 and Tesla's Model S entering the market with deliveries starting in June 2012.
# --------------------------------------------------------------------------------
#
# === 완료 ===
# 총 6개 질문에 대한 RAG 체인 출력값을 생성했습니다.
# 결과가 'data/rag_results_en.csv'에 저장되었습니다.

# %% [markdown]
# `(3) 평가 수행`
#
# - **LLMContextRecall**
#     - 검색 기반 응답 생성 시스템의 **컨텍스트 검색 성능**을 평가
#
# - **Faithfulness**
#     - 검색된 컨텍스트에 대한 응답의 **충실도**를 측정하는 메트릭
#
# - **FactualCorrectness**
#     - 생성된 응답의 **사실 정확성**을 평가

# %%
from ragas import evaluate
from ragas.llms import LangchainLLMWrapper
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness

# LLM 래퍼 생성
evaluator_llm = LangchainLLMWrapper(llm)

# 평가
result = evaluate(
    dataset=evaluation_dataset,   # 평가 데이터셋
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness()],   # 평가 메트릭
    llm=evaluator_llm,   # LLM 래퍼
    callbacks=[langfuse_handler],   # 콜백
)

result
# Out:
# Evaluating:   0%|          | 0/147 [00:00<?, ?it/s]
# {'context_recall': 0.8633, 'faithfulness': 0.8941, 'factual_correctness(mode=f1)': 0.6329}

# %%
# 결과를 데이터프레임으로 변환 
result.to_pandas()
# Out:
#                                            user_input  \
# 0   Tesla, Inc.는 미국에서 어떤 역할을 하고 있으며, 이 회사의 주요 제품과 ...
# 1                     Forbes Global 2000에서 테슬라 순위 뭐야?
# 2                                  Tesla는 언제 누가 만들었나?
# 3                    Larry Page는 전기차 시장에서 어떤 역할을 했나요?
# 4                           Toyota와 Tesla의 관계는 무엇인가요?
# 5                Tesla의 Model 3에 대한 정보를 어디서 찾을 수 있나요?
# 6                                    Tesla Energy 뭐야?
# 7                      2020년 3월에 Tesla의 주요 사건은 무엇입니까?
# 8    Megafactory가 Tesla의 사업 확장에 어떻게 기여했는지 설명해줄 수 있나요?
# 9              Tesla가 Bitcoin에 투자하고 나중에 매각한 이유는 뭐였나요?
# 10             Model S 뭐야? Tesla 차 중에 하나야? 다른 모델도 있어?
# 11         Cybertruck의 제조년도와 좌석 수에 대해 자세히 설명해 주시겠습니까?
# 12                           Model X는 어떤 특징을 가지고 있나요?
# 13  Model 3는 어떤 차체 스타일과 구동 레이아웃을 가지고 있으며, 이 차량의 초기...
# 14  Tesla, Inc.의 Model Y와 Tesla Semi의 주요 특징과 출시 시기...
# 15                          Cybertruck의 모델 종류는 무엇인가요?
# 16                                   로드스터의 특징은 무엇인가요?
# 17                           테슬라의 프리미엄 연결은 무엇을 포함하나요?
# 18                              Telsa는 무슨 서비스를 제공하나요?
# 19  Tesla의 Supercharger 네트워크는 전기차 충전 인프라에서 어떤 역할을 ...
# 20             Tesla는 배터리 공급업체로서 CATL을 어떻게 활용하고 있습니까?
# 21                Tesla는 미국 전기차 시장에서 어떤 기술을 사용하고 있나요?
# 22                Tesla는 어떤 주요 기술을 사용하여 차량 하체를 제작합니까?
# 23                      Gigafactory 뉴욕의 주요 제품은 무엇인가요?
# 24  미국에서 텍사스 주 오스틴에 위치한 Gigafactory 텍사스의 생산 모델은 무엇...
# 25       R. J. 스캐린지가 설립한 Rivian의 초기 역사와 최근 성과는 무엇인가요?
# 26                         R1T의 출시와 관련된 주요 사건은 무엇인가요?
# 27  로드스터의 생산 시작과 단종 시점은 언제였으며, 이 시기에 Tesla가 미국 에너지...
# 28  Rivian의 R1T 모델은 어떤 특징을 가지고 있으며, 이 모델의 생산과 관련된 ...
# 29  Elon Musk는 Tesla의 초기 자금 조달과 경영 변화에 어떻게 관여했으며, ...
# 30  2020년 3월에 Tesla의 프리몬트 공장 폐쇄와 Model Y 배송 시작이 어떻...
# 31       테슬라의 Cybercab은 어떤 특징을 가지고 있으며, 언제 출시될 예정인가요?
# 32  로드스터의 초기 생산과 2세대 모델의 발표 사이에 테슬라의 금융 및 제품 개발에 어...
# 33  Elon Musk의 560억 달러 급여 패키지가 델라웨어 법원에서 거부된 이유와 T...
# 34  Tesla Energy는 SolarCity 인수 후 어떤 제품과 서비스를 제공하며,...
# 35  Rivian의 R1S 모델은 어떤 과정을 거쳐 생산 준비가 되었으며, 이후 시장에서...
# 36  R1S SUV는 Rivian의 첫 번째 플랫폼에서 어떻게 개발되었고, 2022년에는...
# 37  Tesla의 설립 초기와 Elon Musk의 역할은 무엇이며, 이후 Tesla가 직...
# 38  Elon Musk는 Tesla의 초기 자금 조달을 어떻게 주도했으며, 그의 전략은 ...
# 39       Tesla Motors는 어떻게 시작했고, 그 후에 어떤 주요 변화가 있었나요?
# 40  Gigafactory 뉴욕과 Gigafactory 텍사스의 제품 생산 차이점은 무엇...
# 41  Gigafactory 텍사스는 Tesla의 법적 본사로 이전되었는데, 이 공장에서 ...
# 42  Rivian이 Amazon과의 독점 계약을 종료한 후 어떤 차량을 다른 상업 고객에...
# 43  Tesla의 Cybercab은 어떤 해에 출시될 예정이며, 어떤 서비스에 사용될 계...
# 44  Tesla가 SolarCity 인수하고 Tesla Energy 설립한 후에 Mode...
# 45  2022년 9월에 Rivian과 Mercedes-Benz Group의 합작 투자 발...
# 46  Roadster 생산 시작하고 Tesla가 미국 에너지부 대출 받았는데, 그 후에 ...
# 47  Tesla의 Roadster는 어떤 발전을 거쳐 2025년에 생산될 예정이며, 초기...
# 48  Elon Musk의 560억 달러 급여 패키지가 델라웨어 법원에서 거부된 이유와 그...
#
#                                    retrieved_contexts  \
# 0   [Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사입니다. 이 회사...
# 1   [Tesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (2...
# 2   [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 3   [Elon Musk는 주류 차량으로 확장하기 전에 프리미엄 스포츠카로 시작하는 전략...
# 4   [## 파트너\n\nTesla는 Panasonic과 파트너십을 맺고 있으며 리튬 공...
# 5   [Tesla는 2016년 11월 SolarCity를 26억 달러에 인수하여 Tesl...
# 6   [Tesla Energy는 태양 에너지 생성 시스템과 배터리 에너지 저장 제품을 개...
# 7   [Tesla는 2016년 11월 SolarCity를 26억 달러에 인수하여 Tesl...
# 8   [2023년 3월, Tesla는 잠재적인 관세 영향으로 인해 지연된 Gigafact...
# 9   [2021년 초, Tesla는 Bitcoin에 15억 달러를 투자하고 환경 문제로 ...
# 10  [| Tesla 모델 |          |       |              ...
# 11  [- **Cybertruck:** 2019년 11월에 처음 발표된 풀사이즈 픽업 트...
# 12  [| Tesla 모델 |          |       |              ...
# 13  [- **Model 3:** 패스트백 차체 스타일과 듀얼 모터, 전륜 구동 레이아웃...
# 14  [- **Model Y:** 싱글 모터, 후륜 구동 또는 듀얼 모터, 전륜 구동 레...
# 15  [- **Cybertruck:** 2019년 11월에 처음 발표된 풀사이즈 픽업 트...
# 16  [### 발표된 제품\n\n- **Roadster (2세대):** 2017년에 공개...
# 17  [Tesla 자동차에는 내비게이션을 위한 "표준 연결"이 함께 제공됩니다. "프리미...
# 18  [Tesla는 원격 진단 및 수리를 우선시하여 모바일 기술자를 파견하거나 필요한 경...
# 19  [- **Supercharger 네트워크:** Tesla의 고전압 DC 급속 충전 ...
# 20  [Tesla의 전략은 배터리 비용을 줄이기 위해 고가, 소량 차량으로 시작한 다음 ...
# 21  [Tesla의 전략은 배터리 비용을 줄이기 위해 고가, 소량 차량으로 시작한 다음 ...
# 22  [Tesla의 전략은 배터리 비용을 줄이기 위해 고가, 소량 차량으로 시작한 다음 ...
# 23  [| 개장 | 이름                | 도시                ...
# 24  [| 2022 | Gigafactory 텍사스  | 텍사스 주 오스틴        ...
# 25  [- 2009년 R. J. 스캐린지가 Mainstream Motors로 설립.\n-...
# 26  [- R1T 배송은 2021년 9월에 시작되어 Rivian은 완전 전기 픽업을 소비...
# 27  [Roadster 생산은 2008년에 시작되었습니다. 2009년 1월까지 Tesla...
# 28  [**개요**\n\nRivian은 "스케이트보드" 플랫폼(R1T 및 R1S 모델)을...
# 29  [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 30  [2023년 3월, Tesla는 잠재적인 관세 영향으로 인해 지연된 Gigafact...
# 31  [### 발표된 제품\n\n- **Roadster (2세대):** 2017년에 공개...
# 32  [### 발표된 제품\n\n- **Roadster (2세대):** 2017년에 공개...
# 33  [2024년 12월, 델라웨어 법원은 부적절한 이사회 승인을 이유로 Elon Mus...
# 34  [Tesla Energy는 태양 에너지 생성 시스템과 배터리 에너지 저장 제품을 개...
# 35  [- 2009년 R. J. 스캐린지가 Mainstream Motors로 설립.\n-...
# 36  [- R1T 배송은 2021년 9월에 시작되어 Rivian은 완전 전기 픽업을 소비...
# 37  [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 38  [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 39  [Tesla는 내부 고발자 보복, 근로자 권리 침해, 안전 결함, 홍보 부족, Mu...
# 40  [| 개장 | 이름                | 도시                ...
# 41  [| 2022 | Gigafactory 텍사스  | 텍사스 주 오스틴        ...
# 42  [- 2022년 10월, 느슨한 토크 볼트로 인해 13,000대의 차량을 자발적으로...
# 43  [### 발표된 제품\n\n- **Roadster (2세대):** 2017년에 공개...
# 44  [Tesla는 2016년 11월 SolarCity를 26억 달러에 인수하여 Tesl...
# 45  [- R1T 배송은 2021년 9월에 시작되어 Rivian은 완전 전기 픽업을 소비...
# 46  [Tesla의 차량 생산은 2008년 Roadster로 시작하여 Model S (2...
# 47  [### 발표된 제품\n\n- **Roadster (2세대):** 2017년에 공개...
# 48  [2024년 12월, 델라웨어 법원은 부적절한 이사회 승인을 이유로 Elon Mus...
#
#                                              response  \
# 0   Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사로서 전기 자동차(...
# 1             Forbes Global 2000에서 테슬라는 69위에 랭크되었습니다.
# 2   Tesla는 2003년 7월 1일에 Martin Eberhard와 Marc Tarp...
# 3   Larry Page는 Tesla의 후속 자금 조달에 투자자로 참여하여 전기차 시장에...
# 4                           Toyota는 Tesla의 이전 파트너입니다.
# 5   Tesla의 Model 3에 대한 정보는 다음 두 부분에서 찾을 수 있습니다:\n\...
# 6   Tesla Energy는 태양 에너지 생성 시스템과 배터리 에너지 저장 제품을 개발...
# 7   2020년 3월에 Tesla는 COVID-19 팬데믹으로 인해 프리몬트 공장을 폐쇄...
# 8   Megafactory는 2022년에 설립된 Tesla의 새로운 시설로, 캘리포니아에...
# 9   Tesla는 2021년 초에 Bitcoin에 15억 달러를 투자하고 잠시 결제 수단...
# 10  Model S는 Tesla의 전기 자동차 모델 중 하나입니다. 2012년에 출시된 ...
# 11  Cybertruck은 2023년에 제조된 풀사이즈 전기 픽업 트럭입니다. 좌석 수는...
# 12  Model X는 듀얼 모터 또는 트리 모터, 전륜 구동 레이아웃을 갖춘 중형 고급 ...
# 13  Model 3는 패스트백 차체 스타일을 가지고 있으며, 듀얼 모터 전륜 구동 레이아...
# 14  Tesla, Inc.의 **Model Y**와 **Tesla Semi**는 각각 중...
# 15  Cybertruck의 모델 종류는 후륜 구동, 듀얼 모터 전륜 구동, 트리 모터 전...
# 16  로드스터(2세대)는 2017년에 공개되었으며, 620마일(1,000km)의 주행 거...
# 17  테슬라의 프리미엄 연결은 구독료로 실시간 교통 정보, 위성 지도, 인터넷 검색 및 ...
# 18  Tesla는 다음과 같은 서비스를 제공합니다:\n\n1. **차량 서비스**: 원격...
# 19  Tesla의 Supercharger 네트워크는 고전압 DC 급속 충전 네트워크로서,...
# 20  Tesla는 배터리 공급업체로서 CATL에서 공급받은 원통형 및 각형 배터리 셀을 ...
# 21  Tesla는 미국 전기차 시장에서 다음과 같은 기술을 사용하고 있습니다:\n\n- ...
# 22  Tesla는 대형 주조 기계(Giga Press)를 사용하여 대형 단일 피스 하체를...
# 23  Gigafactory 뉴욕의 주요 제품은 Solar Roof와 Supercharge...
# 24  Gigafactory 텍사스에서 생산하는 모델은 Model Y와 Cybertruck...
# 25  R. J. 스캐린지는 2009년에 Mainstream Motors라는 이름으로 회사...
# 26  R1T의 출시와 관련된 주요 사건은 다음과 같습니다:\n\n- 2017년 12월, ...
# 27  로드스터의 생산은 2008년에 시작되었으며, 단종 시점에 대한 구체적인 언급은 없으...
# 28  Rivian의 R1T 모델은 4개의 전기 모터가 장착된 전기 픽업 트럭으로, 배터리...
# 29  Elon Musk는 2004년 2월에 Tesla의 시리즈 A 자금 조달을 주도하여 ...
# 30  2020년 3월에 Tesla는 COVID-19 팬데믹으로 인해 프리몬트 공장을 일시...
# 31  테슬라의 Cybercab은 2인승 배터리 전기 자율 주행차이며, 2026년에 출시될...
# 32  로드스터의 초기 생산(2008년~2012년)과 2세대 모델 발표(2017년 공개, ...
# 33  Elon Musk의 560억 달러 급여 패키지는 부적절한 이사회 승인 이유로 202...
# 34  Tesla Energy는 SolarCity를 2016년 11월에 인수한 후 태양 에...
# 35  Rivian의 R1S 모델은 2017년 12월에 첫 공개되었으며, 생산 준비 과정에...
# 36  R1S SUV는 Rivian의 첫 번째 "스케이트보드" 플랫폼을 기반으로 개발된 스...
# 37  Tesla는 2003년 7월 Martin Eberhard와 Marc Tarpenni...
# 38  Elon Musk는 2004년 2월에 750만 달러의 시리즈 A 자금 조달을 주도하...
# 39  Tesla Motors는 2003년 7월 1일 Martin Eberhard와 Mar...
# 40  Gigafactory 뉴욕은 Solar Roof와 Supercharger를 생산하는...
# 41  Gigafactory 텍사스에서 생산되는 주요 차량 모델은 Model Y와 Cybe...
# 42  Rivian은 Amazon과의 독점 계약을 종료한 후 상업용 전기 밴인 Electr...
# 43  Tesla의 Cybercab은 2026년에 출시될 예정이며, 미래의 차량 호출 서비...
# 44  Tesla는 2016년 11월에 SolarCity를 26억 달러에 인수하여 Tesl...
# 45  2022년 9월, Rivian과 Mercedes-Benz Group이 유럽에서 전기...
# 46  Tesla는 2008년 Roadster 생산을 시작한 이후, 지속적으로 신모델을 출...
# 47  Tesla의 Roadster는 2008년부터 2012년까지 생산된 2인승 스포츠카로...
# 48  Elon Musk의 560억 달러 급여 패키지는 2024년 12월 델라웨어 법원에서...
#
#                                             reference  context_recall  \
# 0   Tesla, Inc.는 미국의 다국적 자동차 및 청정 에너지 회사로, 전기 자동차(...        1.000000
# 1             테슬라는 Forbes Global 2000에서 69위에 랭크되었습니다.        1.000000
# 2   Tesla Motors, Inc.는 2003년 7월 1일에 Martin Eberha...        1.000000
# 3   Larry Page는 전기차 시장에서 Tesla의 후속 자금 조달에 투자한 기업가 ...        1.000000
# 4   2010년 5월, Tesla는 캘리포니아 주 프리몬트의 NUMMI 공장을 Toyot...        0.000000
# 5       제공된 문맥에는 Tesla의 Model 3에 대한 정보가 포함되어 있지 않습니다.        0.000000
# 6   Tesla는 2016년 11월 SolarCity를 26억 달러에 인수하여 Tesla...        1.000000
# 7   2020년 3월에 Tesla는 Model Y 중형 크로스오버 SUV의 배송을 시작했...        0.000000
# 8   Tesla는 2022년에 Megafactory를 통해 캘리포니아에서의 입지를 확장했...        1.000000
# 9   Tesla는 2021년 초에 Bitcoin에 15억 달러를 투자했으나, 환경 문제로...        1.000000
# 10  2024년 11월 현재 Tesla는 Model S를 포함하여 Model X, Mod...        1.000000
# 11            Cybertruck은 2023년에 제조되었으며, 좌석 수는 5개입니다.        1.000000
# 12  Model X는 듀얼 모터 또는 트리 모터, 전륜 구동 레이아웃을 갖춘 5인승, 6...        1.000000
# 13  Model 3는 패스트백 차체 스타일과 듀얼 모터, 전륜 구동 레이아웃 또는 후륜 ...        1.000000
# 14  Model Y는 싱글 모터, 후륜 구동 또는 듀얼 모터, 전륜 구동 레이아웃을 갖춘...        1.000000
# 15  Cybertruck은 후륜 구동, 듀얼 모터 전륜 구동, 트리 모터 전륜 구동의 세...        1.000000
# 16  Roadster (2세대)는 2017년에 공개되었으며 620마일(1,000km)의 ...        1.000000
# 17  프리미엄 연결은 구독료로 실시간 교통 정보, 위성 지도, 인터넷 검색 및 미디어 스...        1.000000
# 18  Tesla는 원격 진단 및 수리를 우선시하여 모바일 기술자를 파견하거나 필요한 경우...        1.000000
# 19  Tesla의 Supercharger 네트워크는 고전압 DC 급속 충전 네트워크로, ...        1.000000
# 20      Tesla는 CATL에서 공급받은 원통형 및 각형 배터리 셀을 사용하고 있습니다.        1.000000
# 21  Tesla는 무선 업데이트를 사용하여 강력한 온보드 컴퓨터를 통해 기능을 추가하거나...        1.000000
# 22  Tesla는 대형 주조 기계(Giga Press)를 사용하여 대형 단일 피스 하체를...        1.000000
# 23  Gigafactory 뉴욕의 주요 제품은 Solar Roof와 Supercharge...        1.000000
# 24  Gigafactory 텍사스는 미국 텍사스 주 오스틴에 위치하며, Model Y와 ...        1.000000
# 25  R. J. 스캐린지는 2009년 Mainstream Motors를 설립하였고, 20...        1.000000
# 26  R1T의 출시는 2021년 9월에 시작되었으며, Rivian은 이를 통해 완전 전기...        1.000000
# 27  로드스터의 생산은 2008년에 시작되었고, 2012년에 단종되었습니다. 이 시기에 ...        0.500000
# 28  Rivian의 R1T 모델은 4개의 전기 모터가 장착된 픽업 트럭으로, 배터리 크기...        1.000000
# 29  Elon Musk는 2004년 2월에 750만 달러의 시리즈 A 자금 조달을 주도하...        1.000000
# 30  2020년 3월에 Tesla는 COVID-19 팬데믹의 영향으로 프리몬트 공장을 폐...        0.666667
# 31  테슬라의 Cybercab은 2인승 배터리 전기 자율 주행차로, 2026년에 출시될 ...        0.500000
# 32  로드스터의 초기 생산은 2008년에 시작되었으며, 2009년 1월까지 테슬라는 1억...        1.000000
# 33  Elon Musk의 560억 달러 급여 패키지는 2024년 12월 델라웨어 법원에서...        0.500000
# 34  Tesla Energy는 2016년 11월 SolarCity를 26억 달러에 인수하...        0.800000
# 35  Rivian의 R1S 모델은 2017년 12월에 처음 공개되었으며, 이는 Rivia...        0.750000
# 36  R1S는 Rivian의 첫 번째 플랫폼에서 개발된 스포츠 유틸리티 차량(SUV) 버...        1.000000
# 37  Tesla Motors, Inc.는 2003년 7월 1일 Martin Eberhar...        1.000000
# 38  Elon Musk는 2004년에 Tesla의 초기 자금 조달을 주도하여 2008년에...        1.000000
# 39  Tesla, Inc.는 2003년 7월 Martin Eberhard와 Marc Ta...        1.000000
# 40  Gigafactory 뉴욕은 뉴욕 주 버팔로에 위치하며 Solar Roof와 Sup...        1.000000
# 41  Gigafactory 텍사스는 Tesla의 법적 본사로 이전되었으며, 이 공장에서 ...        1.000000
# 42  Rivian은 Amazon과의 독점 계약을 2023년 10월에 종료함으로써 Elec...        1.000000
# 43  Tesla의 Cybercab은 2026년에 출시될 예정이며, 미래의 차량 호출 서비...        1.000000
# 44  Tesla는 2016년 11월 SolarCity를 26억 달러에 인수하여 Tesla...        0.666667
# 45  2022년 9월, Rivian은 유럽에서 전기 밴을 생산하기 위해 Mercedes-...        0.250000
# 46  Roadster 생산은 2008년에 시작되었고, Tesla는 2009년 6월 미국 ...        1.000000
# 47  Tesla의 Roadster는 2008년부터 2012년까지 생산된 2인승 스포츠카로...        1.000000
# 48  Elon Musk의 560억 달러 급여 패키지는 2024년 12월 델라웨어 법원에서...        0.666667
#
#     faithfulness  factual_correctness(mode=f1)
# 0       0.769231                          0.57
# 1       1.000000                          1.00
# 2       1.000000                          0.67
# 3       0.500000                          0.80
# 4       1.000000                          0.50
# 5       1.000000                          0.00
# 6       1.000000                          0.00
# 7       1.000000                          0.00
# 8       0.500000                          0.36
# 9       0.800000                          0.89
# 10      0.950000                          0.40
# 11      1.000000                          0.25
# 12      1.000000                          1.00
# 13      1.000000                          0.60
# 14      0.842105                          0.89
# 15      1.000000                          1.00
# 16      0.857143                          0.73
# 17      1.000000                          1.00
# 18      1.000000                          0.42
# 19      0.666667                          1.00
# 20      1.000000                          0.80
# 21      1.000000                          0.82
# 22      1.000000                          1.00
# 23      1.000000                          1.00
# 24      1.000000                          0.80
# 25      0.941176                          0.69
# 26      1.000000                          0.43
# 27      0.833333                          0.60
# 28      0.916667                          0.35
# 29      1.000000                          0.64
# 30      0.833333                          0.80
# 31      1.000000                          0.89
# 32      0.863636                          0.52
# 33      0.800000                          0.50
# 34      0.962963                          0.59
# 35      0.833333                          0.33
# 36      0.875000                          0.36
# 37      1.000000                          0.46
# 38      0.800000                          0.50
# 39      0.960000                          0.41
# 40      1.000000                          0.80
# 41      1.000000                          0.86
# 42      0.500000                          0.86
# 43      1.000000                          1.00
# 44      0.466667                          0.67
# 45      1.000000                          0.50
# 46      0.722222                          0.29
# 47      0.615385                          0.86
# 48      1.000000                          0.60

# %%
# 데이터프레임 저장
result.to_pandas().to_csv('data/evaluation_result.csv', index=False)

# %% [markdown]
# ### **[실습] RAGAS 평가 수행**
#
# - "data/*_EN.md" 문서에 대한 RAG 생성 답변을 평가
# - RAGAS 평가 메트릭 적용 (LLMContextRecall, Faithfulness, FactualCorrectness)

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

from ragas import EvaluationDataset, evaluate
from ragas.llms import LangchainLLMWrapper
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness

# English 문서가 없으면 로드
if 'english_data' not in globals():
    english_txt_files = glob(os.path.join('data', '*_EN.md'))
    english_data = load_text_files(english_txt_files)

# 텍스트 분할 (기존 text_splitter 재사용 가능)
english_docs = text_splitter.split_documents(english_data)
print("English 문서 청크 수:", len(english_docs))

# 임베딩 및 Chroma 생성(영어 전용)
embedding_model_en = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store_en = Chroma.from_documents(
    documents=english_docs,
    embedding=embedding_model_en,
    collection_name="db_english_cosine",
    persist_directory="./chroma_db_en",
    collection_metadata={'hnsw:space': 'cosine'},
)

retriever_en = vector_store_en.as_retriever(search_kwargs={"k": 5})

# RAG 체인 구성 (간단한 prompt + LLM)
template = """Answer the question based only on the following context:

[Context]
{context}

[Question]
{query}

[Answer]
"""
prompt = ChatPromptTemplate.from_template(template)
llm_en = ChatOpenAI(model="gpt-4.1-mini", temperature=0)
qa_chain_en = prompt | llm_en | StrOutputParser()

def format_docs(relevant_docs):
    return "\n".join(doc.page_content for doc in relevant_docs)

# 영어 테스트셋 로드(상위 5개만 사용)
testset_en = pd.read_csv('data/testset_en.csv')
testset_en = testset_en.head(5)

# EvaluationDataset 구성
dataset_list = []
for row in testset_en.itertuples(index=False):
    # 컬럼명이 다르면 적절히 바꾸세요 (예: user_input, reference)
    query = getattr(row, 'user_input', None) or getattr(row, 'query', None)
    reference = getattr(row, 'reference', None)
    if query is None:
        continue

    relevant_docs = retriever_en.invoke(query)
    response = qa_chain_en.invoke(
        {"context": format_docs(relevant_docs), "query": query},
        config={"callbacks": [langfuse_handler]},
    )

    dataset_list.append({
        "user_input": query,
        "retrieved_contexts": [rdoc.page_content for rdoc in relevant_docs],
        "response": response,
        "reference": reference,
    })

evaluation_dataset_en = EvaluationDataset.from_list(dataset_list)

# 평가 실행
evaluator_llm = LangchainLLMWrapper(llm_en)
result_en = evaluate(
    dataset=evaluation_dataset_en,
    metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness()],
    llm=evaluator_llm,
    callbacks=[langfuse_handler],
)

# 결과 확인 및 저장
print(result_en.to_pandas().head())
result_en.to_pandas().to_csv('data/evaluation_result_en.csv', index=False)
# Out:
# English 문서 청크 수: 19
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
#                                           user_input  \
# 0                 Wher was Rivian founded in Florid?
# 1  Who is R. J. Scaringe and what is his role in ...
# 2  Can you explain what Cybercab is and how it co...
# 3  When Tesla started shipping the Cybertruck in ...
# 4  Can you explane how the deliveries of Tesla's ...
#
#                                   retrieved_contexts  \
# 0  [Rivian Automotive, Inc. is an American electr...
# 1  [Rivian Automotive, Inc. is an American electr...
# 2  [- In June 2024, Volkswagen Group announced an...
# 3  [In March 2023, Tesla announced plans for Giga...
# 4  [- R1T shipments began in September 2021, maki...
#
#                                             response  \
# 0          Rivian was founded in Rockledge, Florida.
# 1  R. J. Scaringe is the founder of Rivian Automo...
# 2  The provided context does not mention or provi...
# 3  When Tesla started shipping the Cybertruck in ...
# 4  Based on the provided context, Rivian began sh...
#
#                                            reference  context_recall  \
# 0  Rivian Automotive, Inc. was founded in June 20...        1.000000
# 1  R. J. Scaringe founded Rivian in 2009 original...        1.000000
# 2  Cybercab is an upcoming two-passenger battery-...        0.333333
# 3  Tesla began shipping the Cybertruck in Novembe...        0.666667
# 4  Tesla's Model X, a mid-size luxury crossover S...        0.333333
#
#    faithfulness  factual_correctness(mode=f1)
# 0      1.000000                          0.80
# 1      1.000000                          0.29
# 2      1.000000                          0.00
# 3      0.727273                          0.83
# 4      0.600000                          0.81
